# %%
#reading the necessary libraries
import pandas as pd
import numpy as np
import json

# %%
#reading the required dataset
df_US = pd.read_csv("USvideos.csv")

#reading json file as input
with open('US_category_id.json') as json_data:
    d = json.load(json_data)
    json_data.close()

#creating a list of dictionary of json objects    
list_of_json_objects = (d['items'])

#creating a dictionary to store category ids as keys and category names as values
catid_names = {}

for i in range(len(list_of_json_objects)):
    catid_names[i] = list_of_json_objects[i]['snippet']['title']
    

#replacing category_id column with category_name column
for i in range(len(df_US)):
    category = df_US['category_id'][i]
    if category not in catid_names.keys():
        df_US['category_id'][i] = "Other"
    else:
        df_US['category_id'][i] = catid_names[category]
        
        
df_US.rename(columns={'category_id':'category_name'},inplace=True)


#save the csv locally
df_US.to_csv('US.csv')

# %%
#reading json file as input
with open('US_category_id.json') as json_data:
    d = json.load(json_data)
    json_data.close()

#creating a list of dictionary of json objects    
list_of_json_objects = (d['items'])

# %%
#creating a dictionary to store category ids as keys and category names as values
catid_names = {}

for i in range(len(list_of_json_objects)):
    catid_names[i] = list_of_json_objects[i]['snippet']['title']

# %%
#printing the dictionary
catid_names
# Out:
# {0: 'Film & Animation',
#  1: 'Autos & Vehicles',
#  2: 'Music',
#  3: 'Pets & Animals',
#  4: 'Sports',
#  5: 'Short Movies',
#  6: 'Travel & Events',
#  7: 'Gaming',
#  8: 'Videoblogging',
#  9: 'People & Blogs',
#  10: 'Comedy',
#  11: 'Entertainment',
#  12: 'News & Politics',
#  13: 'Howto & Style',
#  14: 'Education',
#  15: 'Science & Technology',
#  16: 'Movies',
#  17: 'Anime/Animation',
#  18: 'Action/Adventure',
#  19: 'Classics',
#  20: 'Comedy',
#  21: 'Documentary',
#  22: 'Drama',
#  23: 'Family',
#  24: 'Foreign',
#  25: 'Horror',
#  26: 'Sci-Fi/Fantasy',
#  27: 'Thriller',
#  28: 'Shorts',
#  29: 'Shows',
#  30: 'Trailers'}

# %%
df_US.head()
# Out:
#       video_id trending_date  \
# 0  5ugKfHgsmYw      18.07.02
# 1  ohObafdd34Y      18.07.02
# 2  aBr2kKAHN6M      18.07.02
# 3  5wNnwChvmsQ      18.07.02
# 4  B7J47qFvdsk      18.07.02
#
#                                                title  \
# 0  é™¸è‡ªãƒ˜ãƒªã€åž‚ç›´ã«è½ä¸‹ï¼è·¯ä¸Šã®è»Šã...
# 1  ã‚¤ãƒƒãƒ†Q ãŠç¥­ã‚Šç”·å®®å·Ã—æ‰‹è¶Š å·¨å¤§ãƒ...
# 2                              Live Views of Starman
# 3  æ±äº¬ãƒ‡ã‚£ã‚ºãƒ‹ãƒ¼ãƒªã‚¾ãƒ¼ãƒˆã®å…ƒã‚­ãƒ£ã...
# 4  æ¦®å€‰å¥ˆã€…ã€è¡æ’ƒã®æ­»ã‚“ã ãµã‚Šï¼æ˜ ç...
#
#                     channel_title  category_id              publish_time  \
# 0  æ™‚äº‹é€šä¿¡æ˜ åƒã‚»ãƒ³ã‚¿ãƒ¼           25  2018-02-06T03:04:37.000Z
# 1  ç¥žè°·ãˆã‚Šãª Kamiya Erina 2            1  2018-02-06T04:01:56.000Z
# 2                          SpaceX           28  2018-02-06T21:38:22.000Z
# 3           ã‚¢ã‚·ã‚¿ãƒŽãƒ¯ãƒ€ã‚¤           25  2018-02-06T06:08:49.000Z
# 4           ã‚·ãƒãƒžãƒˆã‚¥ãƒ‡ã‚¤            1  2018-02-06T02:30:00.000Z
#
#                                                 tags    views   likes  \
# 0  äº‹æ•…|"ä½è³€"|"ä½è³€çœŒ"|"ãƒ˜ãƒªã‚³ãƒ—ã‚¿ãƒ...   188085     591
# 1                                             [none]    90929     442
# 2                                             [none]  6408303  165892
# 3                              ã‚¢ã‚·ã‚¿ãƒŽãƒ¯ãƒ€ã‚¤    96255    1165
# 4                                             [none]   108408    1336
#
#    dislikes  comment_count                                  thumbnail_link  \
# 0       189              0  https://i.ytimg.com/vi/5ugKfHgsmYw/default.jpg
# 1        88            174  https://i.ytimg.com/vi/ohObafdd34Y/default.jpg
# 2      2331           3006  https://i.ytimg.com/vi/aBr2kKAHN6M/default.jpg
# 3       277            545  https://i.ytimg.com/vi/5wNnwChvmsQ/default.jpg
# 4        74            201  https://i.ytimg.com/vi/B7J47qFvdsk/default.jpg
#
#    comments_disabled  ratings_disabled  video_error_or_removed  \
# 0               True             False                   False
# 1              False             False                   False
# 2              False             False                   False
# 3              False             False                   False
# 4              False             False                   False
#
#                                          description
# 0  ä½è³€çœŒç¥žåŸ¼å¸‚ã®æ°‘å®¶ã«å¢œè½ã—ãŸé™¸ä...
# 1                                                NaN
# 2                                                NaN
# 3  æ±äº¬ãƒ‡ã‚£ã‚ºãƒ‹ãƒ¼ãƒªã‚¾ãƒ¼ãƒˆã®å…ƒã‚­ãƒ£ã...
# 4  å®¶ã«å¸°ã£ã¦ããŸã‚µãƒ©ãƒªãƒ¼ãƒžãƒ³ã®ã˜ã...

# %%
#replacing category_id column with category_name column
for i in range(len(df_US)):
    category = df_US['category_id'][i]
    if category not in catid_names.keys():
        df_US['category_id'][i] = "Other"
    else:
        df_US['category_id'][i] = catid_names[category]
# Out:
# C:\Users\Aishwarya\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# C:\Users\Aishwarya\Anaconda3\lib\site-packages\pandas\core\indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_US
# Out:
#           video_id trending_date  \
# 0      5ugKfHgsmYw      18.07.02
# 1      ohObafdd34Y      18.07.02
# 2      aBr2kKAHN6M      18.07.02
# 3      5wNnwChvmsQ      18.07.02
# 4      B7J47qFvdsk      18.07.02
# ...            ...           ...
# 20518  GuWCkLnCMOo      18.14.06
# 20519  nOUlB0i2MaA      18.14.06
# 20520  4cRanIowkTE      18.14.06
# 20521  oLtWIVBVoS8      18.14.06
# 20522  2IEWv23oa9E      18.14.06
#
#                                                    title  \
# 0      é™¸è‡ªãƒ˜ãƒªã€åž‚ç›´ã«è½ä¸‹ï¼è·¯ä¸Šã®è»Šã...
# 1      ã‚¤ãƒƒãƒ†Q ãŠç¥­ã‚Šç”·å®®å·Ã—æ‰‹è¶Š å·¨å¤§ãƒ...
# 2                                  Live Views of Starman
# 3      æ±äº¬ãƒ‡ã‚£ã‚ºãƒ‹ãƒ¼ãƒªã‚¾ãƒ¼ãƒˆã®å…ƒã‚­ãƒ£ã...
# 4      æ¦®å€‰å¥ˆã€…ã€è¡æ’ƒã®æ­»ã‚“ã ãµã‚Šï¼æ˜ ç...
# ...                                                  ...
# 20518  à¸«à¸™à¸¶à¹ˆà¸‡à¸”à¹‰à¸²à¸§à¸Ÿà¹‰à¸²à¹€à¸”à¸µà...
# 20519  2018 êµ­ë¯¼ì˜ ì„ íƒ - ì„ ê±°ë°©ì†¡ 'ì™•ì˜ ê...
# 20520  å…ƒFBIã‚¨ãƒ¼ã‚¸ã‚§ãƒ³ãƒˆãŒæ•™ãˆã‚‹ã€200ï¼…ä...
# 20521  æ—¥æœ¬Ã—ãƒ‘ãƒ©ã‚°ã‚¢ã‚¤å¾¹åº•åˆ†æž&ã‚¹ãƒšã‚¤ã...
# 20522  ã‚¨ã‚µã®ã‚³ã‚ªãƒ­ã‚®ã«å¤¢ä¸­ã§äºŒæœ¬è¶³ã§ç...
#
#                                    channel_title       category_id  \
# 0                 æ™‚äº‹é€šä¿¡æ˜ åƒã‚»ãƒ³ã‚¿ãƒ¼            Horror
# 1                 ç¥žè°·ãˆã‚Šãª Kamiya Erina 2  Autos & Vehicles
# 2                                         SpaceX            Shorts
# 3                          ã‚¢ã‚·ã‚¿ãƒŽãƒ¯ãƒ€ã‚�
äº¬ãƒ‡ã‚£ã‚ºãƒ‹ãƒ¼ãƒªã‚¾ãƒ¼ãƒˆã®å…ƒã‚­ãƒ£ã...
# 4      å®¶ã«å¸°ã£ã¦ããŸã‚µãƒ©ãƒªãƒ¼ãƒžãƒ³ã®ã˜ã...
# ...                                                  ...
# 20518  à¸«à¸¥à¸±à¸‡à¸ˆà¸šà¸¥à¸°à¸„à¸£à¸—à¸²à¸‡à¸«à¸™à...
# 20519  'ì„ ê±°ë°©ì†¡ì˜ ëª…ê°€' SBSê°€ ì˜¨ë‹¤! SBSê°€...
# 20520  å…ƒFBIã‚¨ãƒ¼ã‚¸ã‚§ãƒ³ãƒˆã€ã‚¸ãƒ£ãƒƒã‚¯ï½¥ã‚·ã...
# 20521  ã€Œï¼’ï¼ï¼‘ï¼˜ï¼·æ¯ãƒ­ã‚·ã‚¢å¤§ä¼šæ—¥æœ¬ä»£è...
# 20522  ä½¿ç”¨ã—ãŸç‰©https://amzn.to/2JwOEPGãƒ¡ã‚¤ãƒ...
#
# [20523 rows x 16 columns]

# %%
df_US.rename(columns={'category_id':'category_name'},inplace=True)

# %%
df_US.head()
# Out:
#       video_id trending_date  \
# 0  5ugKfHgsmYw      18.07.02
# 1  ohObafdd34Y      18.07.02
# 2  aBr2kKAHN6M      18.07.02
# 3  5wNnwChvmsQ      18.07.02
# 4  B7J47qFvdsk      18.07.02
#
#                                                title  \
# 0  é™¸è‡ªãƒ˜ãƒªã€åž‚ç›´ã«è½ä¸‹ï¼è·¯ä¸Šã®è»Šã...
# 1  ã‚¤ãƒƒãƒ†Q ãŠç¥­ã‚Šç”·å®®å·Ã—æ‰‹è¶Š å·¨å¤§ãƒ...
# 2                              Live Views of Starman
# 3  æ±äº¬ãƒ‡ã‚£ã‚ºãƒ‹ãƒ¼ãƒªã‚¾ãƒ¼ãƒˆã®å…ƒã‚­ãƒ£ã...
# 4  æ¦®å€‰å¥ˆã€…ã€è¡æ’ƒã®æ­»ã‚“ã ãµã‚Šï¼æ˜ ç...
#
#                     channel_title     category_name              publish_time  \
# 0  æ™‚äº‹é€šä¿¡æ˜ åƒã‚»ãƒ³ã‚¿ãƒ¼            Horror  2018-02-06T03:04:37.000Z
# 1  ç¥žè°·ãˆã‚Šãª Kamiya Erina 2  Autos & Vehicles  2018-02-06T04:01:56.000Z
# 2                          SpaceX            Shorts  2018-02-06T21:38:22.000Z
# 3           ã‚¢ã‚·ã‚¿ãƒŽãƒ¯ãƒ€ã‚¤            Horror  2018-02-06T06:08:49.000Z
# 4           ã‚·ãƒãƒžãƒˆã‚¥ãƒ‡ã‚¤  Autos & Vehicles  2018-02-06T02:30:00.000Z
#
#                                                 tags    views   likes  \
# 0  äº‹æ•…|"ä½è³€"|"ä½è³€çœŒ"|"ãƒ˜ãƒªã‚³ãƒ—ã‚¿ãƒ...   188085     591
# 1                                             [none]    90929     442
# 2                                             [none]  6408303  165892
# 3                              ã‚¢ã‚·ã‚¿ãƒŽãƒ¯ãƒ€ã‚¤    96255    1165
# 4                                             [none]   108408    1336
#
#    dislikes  comment_count                                  thumbnail_link  \
# 0       189              0  https://i.ytimg.com/vi/5ugKfHgsmYw/default.jpg
# 1        88            174  https://i.ytimg.com/vi/ohObafdd34Y/default.jpg
# 2      2331           3006  https://i.ytimg.com/vi/aBr2kKAHN6M/default.jpg
# 3       277            545  https://i.ytimg.com/vi/5wNnwChvmsQ/default.jpg
# 4        74            201  https://i.ytimg.com/vi/B7J47qFvdsk/default.jpg
#
#    comments_disabled  ratings_disabled  video_error_or_removed  \
# 0               True             False                   False
# 1              False             False                   False
# 2              False             False                   False
# 3              False             False                   False
# 4              False             False                   False
#
#                                          description
# 0  ä½è³€çœŒç¥žåŸ¼å¸‚ã®æ°‘å®¶ã«å¢œè½ã—ãŸé™¸ä...
# 1                                                NaN
# 2                                                NaN
# 3  æ±äº¬ãƒ‡ã‚£ã‚ºãƒ‹ãƒ¼ãƒªã‚¾ãƒ¼ãƒˆã®å…ƒã‚­ãƒ£ã...
# 4  å®¶ã«å¸°ã£ã¦ããŸã‚µãƒ©ãƒªãƒ¼ãƒžãƒ³ã®ã˜ã...

# %%
#save the csv locally
df_US.to_csv('US.csv')

# %%
# Aish job :
#convert category ids to category names by mapping their values to corresponding json file
